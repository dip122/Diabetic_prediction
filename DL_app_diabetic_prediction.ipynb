# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets.csv')

# %%
df.head(1)
# Out:
#    6  148  72  35  0  33.6  0.627  50  1
# 0  1   85  66  29  0  26.6  0.351  31  0

# %%
df.rename(columns = {'6' : 'Pregnancies' , '148' : 'Glucose' , '72' : 'BloodPressure' , '35' : 'SkinThickness' , '0' : 'Insulin' , '33.6' : 'BMI' , '0.627' : 'DiabetesPedigreeFunction' , '50' : 'Age' , '1' : 'outcome'},inplace =True)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  outcome
# 0                     0.351   31        0
# 1                     0.672   32        1
# 2                     0.167   21        0
# 3                     2.288   33        1
# 4                     0.201   30        0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   767.000000  767.000000     767.000000     767.000000  767.000000
# mean      3.842243  120.859192      69.101695      20.517601   79.903520
# std       3.370877   31.978468      19.368155      15.954059  115.283105
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   32.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     outcome
# count  767.000000                767.000000  767.000000  767.000000
# mean    31.990482                  0.471674   33.219035    0.348110
# std      7.889091                  0.331497   11.752296    0.476682
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243500   24.000000    0.000000
# 50%     32.000000                  0.371000   29.000000    0.000000
# 75%     36.600000                  0.625000   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               767 non-null    int64
#  1   Glucose                   767 non-null    int64
#  2   BloodPressure             767 non-null    int64
#  3   SkinThickness             767 non-null    int64
#  4   Insulin                   767 non-null    int64
#  5   BMI                       767 non-null    float64
#  6   DiabetesPedigreeFunction  767 non-null    float64
#  7   Age                       767 non-null    int64
#  8   outcome                   767 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.duplicated().sum()   # no duplicate value is present
# Out:
# 0

# %%
df['outcome'].value_counts()    # data is not so biased
# Out:
# 0    500
# 1    267
# Name: outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns = ['outcome']);
y = df['outcome']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 1)

# %%
X.shape
# Out:
# (767, 8)

# %%
y.shape
# Out:
# (767,)

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.351   31
# 1                     0.672   32
# 2                     0.167   21
# 3                     2.288   33
# 4                     0.201   30

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 1.49469849,  0.70529254,  0.57078307, ...,  0.73884819,
#          0.55721449,  0.58496446],
#        [ 1.7896921 ,  0.20300462, -0.37203436, ...,  1.1680149 ,
#         -0.05569033,  0.4142512 ],
#        [-1.16024406, -0.26789031,  0.57078307, ...,  1.55816646,
#         -0.91250626, -0.52467177],
#        ...,
#        [ 0.01973041,  0.20300462,  0.88505555, ...,  0.37470673,
#         -0.71237407, -0.8660983 ],
#        [ 0.90471125,  1.83544037,  0.78029806, ...,  0.47874715,
#          0.39773416,  1.52388743],
#        [-0.57025683, -1.02132219, -0.05776188, ...,  0.77786334,
#          0.13818772, -0.52467177]])

# %%
X_test_scaled
# Out:
# array([[ 0.31472402,  1.0192225 ,  0.78029806, ...,  0.8428886 ,
#          0.50092731,  0.07282466],
#        [-1.16024406,  0.07743264,  1.40884301, ..., -1.26392981,
#         -0.61543504, -1.03681157],
#        [ 2.37967934, -0.04813934,  0.46602558, ..., -0.74372773,
#         -0.62481624,  2.4628104 ],
#        ...,
#        [ 0.90471125,  0.92504351,  0.98981304, ...,  2.31245947,
#         -0.38090514,  0.24353793],
#        [ 0.31472402,  0.42275559,  0.67554056, ..., -4.1900665 ,
#          0.56659569,  3.06030683],
#        [ 0.01973041, -1.02132219, -3.61951661, ..., -0.54865195,
#          0.47278373, -0.18324524]])

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
#1st layer 8 input so input_dim = 8 and activation function which is used is relu
# 12 repersent number of nodes in the hidden layer 1
model.add(Dense(12,input_dim = 8,activation = 'relu'))
#2nd layer ....for next layer 8 nodes is present
model.add(Dense(8,activation = 'relu'))
model.add(Dense(1,activation = 'relu'))

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                108
#
#  dense_1 (Dense)             (None, 8)                 104
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 221 (884.00 Byte)
# Trainable params: 221 (884.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = 'binary_crossentropy',optimizer = 'Adam')  # it is a binary classification so binary_crossentropy

# %%
model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6334
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6266
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6195
# Epoch 4/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6137
# Epoch 5/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.6087
# Epoch 6/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5839
# Epoch 7/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5570
# Epoch 8/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5522
# Epoch 9/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5469
# Epoch 10/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5437
# Epoch 11/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5403
# Epoch 12/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5365
# Epoch 13/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5336
# Epoch 14/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5309
# Epoch 15/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5312
# Epoch 16/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5278
# Epoch 17/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5243
# Epoch 18/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5223
# Epoch 19/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5211
# Epoch 20/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5183
# Epoch 21/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5175
# Epoch 22/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5168
# Epoch 23/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5159
# Epoch 24/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5122
# Epoch 25/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5105
# Epoch 26/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5103
# Epoch 27/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5097
# Epoch 28/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5066
# Epoch 29/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5051
# Epoch 30/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5046
# Epoch 31/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5031
# Epoch 32/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5020
# Epoch 33/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5018
# Epoch 34/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.5016
# Epoch 35/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4991
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4985
# Epoch 37/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4975
# Epoch 38/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4972
# Epoch 39/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4971
# Epoch 40/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4966
# Epoch 41/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4963
# Epoch 42/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4932
# Epoch 43/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4926
# Epoch 44/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4924
# Epoch 45/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4935
# Epoch 46/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4906
# Epoch 47/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4903
# Epoch 48/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4891
# Epoch 49/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4884
# Epoch 50/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4865
# Epoch 51/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4853
# Epoch 52/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4853
# Epoch 53/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4842
# Epoch 54/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4833
# Epoch 55/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4827
# Epoch 56/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4810
# Epoch 57/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4808
# Epoch 58/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4803
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4786
# Epoch 60/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4777
# Epoch 61/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4770
# Epoch 62/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4758
# Epoch 63/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4750
# Epoch 64/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4740
# Epoch 65/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4733
# Epoch 66/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4731
# Epoch 67/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4722
# Epoch 68/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4718
# Epoch 69/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4707
# Epoch 70/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4701
# Epoch 71/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4696
# Epoch 72/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4687
# Epoch 73/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4680
# Epoch 74/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4675
# Epoch 75/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4680
# Epoch 76/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4664
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4663
# Epoch 78/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4649
# Epoch 79/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4746
# Epoch 80/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4698
# Epoch 81/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4635
# Epoch 82/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4633
# Epoch 83/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4619
# Epoch 84/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4612
# Epoch 85/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4608
# Epoch 86/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4598
# Epoch 87/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4599
# Epoch 88/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4585
# Epoch 89/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4585
# Epoch 90/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4562
# Epoch 91/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4565
# Epoch 92/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4563
# Epoch 93/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4549
# Epoch 94/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4547
# Epoch 95/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4540
# Epoch 96/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4537
# Epoch 97/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4528
# Epoch 98/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4522
# Epoch 99/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4521
# Epoch 100/100
# 20/20 [==============================] - 0s 1ms/step - loss: 0.4511

# %%
y_log = model.predict(X_test_scaled)
y_log
# Out:
# 5/5 [==============================] - 0s 2ms/step
# array([[0.7519184 ],
#        [0.        ],
#        [0.2578749 ],
#        [0.        ],
#        [0.        ],
#        [0.4769672 ],
#        [0.        ],
#        [0.29938754],
#        [0.24932726],
#        [0.        ],
#        [0.5114506 ],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.51945984],
#        [0.47337812],
#        [0.21983501],
#        [0.06966104],
#        [0.        ],
#        [0.        ],
#        [0.37427896],
#        [0.35403153],
#        [0.27913287],
#        [0.15312882],
#        [0.        ],
#        [0.19538067],
#        [0.        ],
#        [0.        ],
#        [0.68117636],
#        [0.27682766],
#        [0.3560852 ],
#        [0.3334451 ],
#        [0.6751725 ],
#        [0.        ],
#        [0.9112656 ],
#        [0.        ],
#        [0.56435335],
#        [0.70883334],
#        [0.12545408],
#        [0.2840809 ],
#        [0.16228501],
#        [0.3710733 ],
#        [0.27439824],
#        [0.        ],
#        [0.15040009],
#        [0.2165113 ],
#        [0.04075506],
#        [0.        ],
#        [0.44894698],
#        [0.22646932],
#        [0.29451934],
#        [0.06919735],
#        [0.78541696],
#        [0.08382797],
#        [0.        ],
#        [0.25572726],
#        [1.3370167 ],
#        [0.38145107],
#        [0.4296977 ],
#        [0.6150869 ],
#        [0.39814544],
#        [0.        ],
#        [0.3479441 ],
#        [0.1086266 ],
#        [0.        ],
#        [0.15820557],
#        [0.5365476 ],
#        [0.5122371 ],
#        [0.4579757 ],
#        [0.5958546 ],
#        [0.8650351 ],
#        [0.542763  ],
#        [0.        ],
#        [0.6942296 ],
#        [0.6134348 ],
#        [0.42989746],
#        [0.22398332],
#        [0.        ],
#        [0.        ],
#        [0.22401597],
#        [0.6032454 ],
#        [1.2095128 ],
#        [0.5244973 ],
#        [0.63184786],
#        [0.        ],
#        [0.5267434 ],
#        [1.018549  ],
#        [0.1872795 ],
#        [0.        ],
#        [0.04282591],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.71892834],
#        [0.        ],
#        [0.        ],
#        [0.38358054],
#        [0.3035828 ],
#        [0.        ],
#        [0.5415075 ],
#        [0.34968942],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.5971806 ],
#        [0.        ],
#        [0.        ],
#        [0.34391984],
#        [0.55276597],
#        [0.17085838],
#        [1.2943063 ],
#        [0.32187983],
#        [0.5315155 ],
#        [0.35186505],
#        [0.7730455 ],
#        [0.6124616 ],
#        [0.47175336],
#        [0.50867814],
#        [0.7541578 ],
#        [0.        ],
#        [0.        ],
#        [0.24067064],
#        [1.3515457 ],
#        [0.5719801 ],
#        [0.24243835],
#        [1.2140096 ],
#        [0.5675535 ],
#        [0.        ],
#        [0.        ],
#        [0.33075967],
#        [0.26237372],
#        [0.5645962 ],
#        [0.34389699],
#        [0.6007105 ],
#        [0.6903868 ],
#        [0.66061026],
#        [0.19034319],
#        [0.        ],
#        [0.        ],
#        [1.4247417 ],
#        [0.        ],
#        [0.17939605],
#        [0.7513772 ],
#        [0.        ],
#        [0.34487468],
#        [0.        ],
#        [0.29839194],
#        [0.78973734],
#        [0.03087183],
#        [0.76017666],
#        [0.7308233 ],
#        [0.2647155 ],
#        [0.23336895]], dtype=float32)

# %%
y_pred = np.where(y_log>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7727272727272727
