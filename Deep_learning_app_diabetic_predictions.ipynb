# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets.csv')

# %%
df.head(1)
# Out:
#    6  148  72  35  0  33.6  0.627  50  1
# 0  1   85  66  29  0  26.6  0.351  31  0

# %%
df.rename(columns = {'6' : 'Pregnancies' , '148' : 'Glucose' , '72' : 'BloodPressure' , '35' : 'SkinThickness' , '0' : 'Insulin' , '33.6' : 'BMI' , '0.627' : 'DiabetesPedigreeFunction' , '50' : 'Age' , '1' : 'outcome'},inplace =True)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  outcome
# 0                     0.351   31        0
# 1                     0.672   32        1
# 2                     0.167   21        0
# 3                     2.288   33        1
# 4                     0.201   30        0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   767.000000  767.000000     767.000000     767.000000  767.000000
# mean      3.842243  120.859192      69.101695      20.517601   79.903520
# std       3.370877   31.978468      19.368155      15.954059  115.283105
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   32.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     outcome
# count  767.000000                767.000000  767.000000  767.000000
# mean    31.990482                  0.471674   33.219035    0.348110
# std      7.889091                  0.331497   11.752296    0.476682
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243500   24.000000    0.000000
# 50%     32.000000                  0.371000   29.000000    0.000000
# 75%     36.600000                  0.625000   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               767 non-null    int64
#  1   Glucose                   767 non-null    int64
#  2   BloodPressure             767 non-null    int64
#  3   SkinThickness             767 non-null    int64
#  4   Insulin                   767 non-null    int64
#  5   BMI                       767 non-null    float64
#  6   DiabetesPedigreeFunction  767 non-null    float64
#  7   Age                       767 non-null    int64
#  8   outcome                   767 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.duplicated().sum()   # no duplicate value is present
# Out:
# 0

# %%
df['outcome'].value_counts()    # data is not so biased
# Out:
# 0    500
# 1    267
# Name: outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns = ['outcome']);
y = df['outcome']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y,random_state=20)

# %%
X.shape
# Out:
# (767, 8)

# %%
y.shape
# Out:
# (767,)

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.351   31
# 1                     0.672   32
# 2                     0.167   21
# 3                     2.288   33
# 4                     0.201   30

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train
# Out:
# array([[-0.84646819, -0.80120377, -0.28213933, ...,  0.16058562,
#         -0.54945455, -1.04620412],
#        [ 0.05594051, -0.10016996,  0.03804224, ...,  1.58595789,
#          1.31023588, -0.61756949],
#        [-1.14727109,  0.15475142,  0.78513255, ..., -0.15476223,
#          0.14906332, -0.78902334],
#        ...,
#        [-1.14727109, -0.51441721, -0.28213933, ...,  1.20754047,
#         -0.90022543, -0.96047719],
#        [-1.14727109, -0.96052963, -0.06868495, ...,  1.00571785,
#         -0.27125696, -0.70329642],
#        [-1.14727109, -0.25949583,  0.57167818, ..., -0.11692049,
#          1.21951928, -1.04620412]])

# %%
X_test
# Out:
# array([[ 1.25915211,  0.37780763,  0.14476942, ...,  0.12274388,
#         -0.6069084 ,  0.49688053],
#        [ 0.05594051,  0.72832453,  0.67840536, ...,  0.82912305,
#          0.25187547,  0.32542668],
#        [ 0.05594051, -0.291361  ,  0.46495099, ...,  0.94264828,
#         -0.70972056,  0.4111536 ],
#        ...,
#        [ 0.65754631, -0.45068687,  0.99858693, ...,  0.61468652,
#          0.7750079 , -0.18893487],
#        [-0.84646819, -0.57814756, -2.09650152, ...,  1.43459092,
#         -0.86998656, -0.01748102],
#        [ 0.05594051, -0.13203514, -0.28213933, ...,  0.16058562,
#         -0.72786388, -0.78902334]])

# %%
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from matplotlib import pyplot as plt
from sklearn.model_selection import StratifiedKFold
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.metrics import accuracy_score

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_51 (Dense)            (None, 64)                576
#
#  dense_52 (Dense)            (None, 32)                2080
#
#  dense_53 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2689 (10.50 KB)
# Trainable params: 2689 (10.50 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Training the model
model.fit(X_train, y_train, epochs=75, batch_size=27, validation_split=0.2)
# Out:
# Epoch 1/75
# 19/19 [==============================] - 1s 18ms/step - loss: 0.6223 - accuracy: 0.6449 - val_loss: 0.5568 - val_accuracy: 0.7398
# Epoch 2/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.5458 - accuracy: 0.7163 - val_loss: 0.5140 - val_accuracy: 0.7642
# Epoch 3/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.5065 - accuracy: 0.7592 - val_loss: 0.4938 - val_accuracy: 0.7561
# Epoch 4/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4863 - accuracy: 0.7612 - val_loss: 0.4815 - val_accuracy: 0.7642
# Epoch 5/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4756 - accuracy: 0.7673 - val_loss: 0.4794 - val_accuracy: 0.7724
# Epoch 6/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4661 - accuracy: 0.7633 - val_loss: 0.4783 - val_accuracy: 0.7967
# Epoch 7/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4606 - accuracy: 0.7653 - val_loss: 0.4775 - val_accuracy: 0.8049
# Epoch 8/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4572 - accuracy: 0.7735 - val_loss: 0.4788 - val_accuracy: 0.7805
# Epoch 9/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4515 - accuracy: 0.7816 - val_loss: 0.4762 - val_accuracy: 0.7805
# Epoch 10/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4479 - accuracy: 0.7857 - val_loss: 0.4805 - val_accuracy: 0.7886
# Epoch 11/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4451 - accuracy: 0.7878 - val_loss: 0.4737 - val_accuracy: 0.7805
# Epoch 12/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4426 - accuracy: 0.7878 - val_loss: 0.4754 - val_accuracy: 0.7886
# Epoch 13/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4397 - accuracy: 0.7816 - val_loss: 0.4766 - val_accuracy: 0.7642
# Epoch 14/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4361 - accuracy: 0.7898 - val_loss: 0.4774 - val_accuracy: 0.7642
# Epoch 15/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4342 - accuracy: 0.7939 - val_loss: 0.4706 - val_accuracy: 0.7642
# Epoch 16/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4324 - accuracy: 0.8041 - val_loss: 0.4706 - val_accuracy: 0.7642
# Epoch 17/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.4301 - accuracy: 0.7878 - val_loss: 0.4763 - val_accuracy: 0.7886
# Epoch 18/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4284 - accuracy: 0.7959 - val_loss: 0.4794 - val_accuracy: 0.8049
# Epoch 19/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4254 - accuracy: 0.7959 - val_loss: 0.4806 - val_accuracy: 0.7805
# Epoch 20/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4222 - accuracy: 0.8020 - val_loss: 0.4787 - val_accuracy: 0.7886
# Epoch 21/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4214 - accuracy: 0.7959 - val_loss: 0.4802 - val_accuracy: 0.7886
# Epoch 22/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.4191 - accuracy: 0.7959 - val_loss: 0.4812 - val_accuracy: 0.7642
# Epoch 23/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4172 - accuracy: 0.8041 - val_loss: 0.4811 - val_accuracy: 0.7805
# Epoch 24/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4151 - accuracy: 0.8000 - val_loss: 0.4772 - val_accuracy: 0.7724
# Epoch 25/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4115 - accuracy: 0.8102 - val_loss: 0.4815 - val_accuracy: 0.7805
# Epoch 26/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4106 - accuracy: 0.8020 - val_loss: 0.4870 - val_accuracy: 0.7724
# Epoch 27/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.4078 - accuracy: 0.8102 - val_loss: 0.4865 - val_accuracy: 0.7724
# Epoch 28/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4067 - accuracy: 0.8184 - val_loss: 0.4847 - val_accuracy: 0.7724
# Epoch 29/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4057 - accuracy: 0.8143 - val_loss: 0.4919 - val_accuracy: 0.7886
# Epoch 30/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4022 - accuracy: 0.8102 - val_loss: 0.4881 - val_accuracy: 0.7724
# Epoch 31/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4004 - accuracy: 0.8143 - val_loss: 0.4894 - val_accuracy: 0.7561
# Epoch 32/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.4000 - accuracy: 0.8163 - val_loss: 0.4979 - val_accuracy: 0.7805
# Epoch 33/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3956 - accuracy: 0.8122 - val_loss: 0.4937 - val_accuracy: 0.7724
# Epoch 34/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3943 - accuracy: 0.8245 - val_loss: 0.4893 - val_accuracy: 0.7642
# Epoch 35/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3919 - accuracy: 0.8204 - val_loss: 0.4859 - val_accuracy: 0.7805
# Epoch 36/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3903 - accuracy: 0.8265 - val_loss: 0.4869 - val_accuracy: 0.7886
# Epoch 37/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3882 - accuracy: 0.8286 - val_loss: 0.4933 - val_accuracy: 0.7805
# Epoch 38/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3865 - accuracy: 0.8224 - val_loss: 0.4975 - val_accuracy: 0.7724
# Epoch 39/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3837 - accuracy: 0.8163 - val_loss: 0.4952 - val_accuracy: 0.7724
# Epoch 40/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3834 - accuracy: 0.8245 - val_loss: 0.4947 - val_accuracy: 0.7642
# Epoch 41/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3817 - accuracy: 0.8286 - val_loss: 0.4981 - val_accuracy: 0.7805
# Epoch 42/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3802 - accuracy: 0.8306 - val_loss: 0.5076 - val_accuracy: 0.7642
# Epoch 43/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3763 - accuracy: 0.8265 - val_loss: 0.5015 - val_accuracy: 0.7805
# Epoch 44/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3750 - accuracy: 0.8286 - val_loss: 0.5073 - val_accuracy: 0.7805
# Epoch 45/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3764 - accuracy: 0.8388 - val_loss: 0.5045 - val_accuracy: 0.7724
# Epoch 46/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3760 - accuracy: 0.8347 - val_loss: 0.5117 - val_accuracy: 0.7724
# Epoch 47/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3690 - accuracy: 0.8327 - val_loss: 0.5055 - val_accuracy: 0.7561
# Epoch 48/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3704 - accuracy: 0.8367 - val_loss: 0.4998 - val_accuracy: 0.7561
# Epoch 49/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3655 - accuracy: 0.8408 - val_loss: 0.5143 - val_accuracy: 0.7561
# Epoch 50/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3640 - accuracy: 0.8388 - val_loss: 0.5167 - val_accuracy: 0.7642
# Epoch 51/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3605 - accuracy: 0.8449 - val_loss: 0.5216 - val_accuracy: 0.7805
# Epoch 52/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3596 - accuracy: 0.8408 - val_loss: 0.5196 - val_accuracy: 0.7480
# Epoch 53/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3577 - accuracy: 0.8367 - val_loss: 0.5271 - val_accuracy: 0.7642
# Epoch 54/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3545 - accuracy: 0.8449 - val_loss: 0.5213 - val_accuracy: 0.7561
# Epoch 55/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3522 - accuracy: 0.8469 - val_loss: 0.5236 - val_accuracy: 0.7724
# Epoch 56/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3496 - accuracy: 0.8469 - val_loss: 0.5276 - val_accuracy: 0.7561
# Epoch 57/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3473 - accuracy: 0.8551 - val_loss: 0.5254 - val_accuracy: 0.7561
# Epoch 58/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3469 - accuracy: 0.8429 - val_loss: 0.5304 - val_accuracy: 0.7642
# Epoch 59/75
# 19/19 [==============================] - 0s 4ms/step - loss: 0.3461 - accuracy: 0.8531 - val_loss: 0.5257 - val_accuracy: 0.7724
# Epoch 60/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3414 - accuracy: 0.8510 - val_loss: 0.5242 - val_accuracy: 0.7724
# Epoch 61/75
# 19/19 [==============================] - 0s 10ms/step - loss: 0.3385 - accuracy: 0.8510 - val_loss: 0.5349 - val_accuracy: 0.7724
# Epoch 62/75
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3384 - accuracy: 0.8571 - val_loss: 0.5274 - val_accuracy: 0.7480
# Epoch 63/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3379 - accuracy: 0.8571 - val_loss: 0.5324 - val_accuracy: 0.7724
# Epoch 64/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3361 - accuracy: 0.8592 - val_loss: 0.5228 - val_accuracy: 0.7561
# Epoch 65/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3327 - accuracy: 0.8653 - val_loss: 0.5277 - val_accuracy: 0.7886
# Epoch 66/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3258 - accuracy: 0.8673 - val_loss: 0.5293 - val_accuracy: 0.7561
# Epoch 67/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3246 - accuracy: 0.8694 - val_loss: 0.5373 - val_accuracy: 0.7561
# Epoch 68/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3237 - accuracy: 0.8612 - val_loss: 0.5433 - val_accuracy: 0.7561
# Epoch 69/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3229 - accuracy: 0.8714 - val_loss: 0.5494 - val_accuracy: 0.7805
# Epoch 70/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3207 - accuracy: 0.8714 - val_loss: 0.5472 - val_accuracy: 0.7642
# Epoch 71/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3146 - accuracy: 0.8776 - val_loss: 0.5643 - val_accuracy: 0.7886
# Epoch 72/75
# 19/19 [==============================] - 0s 6ms/step - loss: 0.3187 - accuracy: 0.8612 - val_loss: 0.5590 - val_accuracy: 0.7886
# Epoch 73/75
# 19/19 [==============================] - 0s 7ms/step - loss: 0.3118 - accuracy: 0.8755 - val_loss: 0.5773 - val_accuracy: 0.7642
# Epoch 74/75
# 19/19 [==============================] - 0s 8ms/step - loss: 0.3134 - accuracy: 0.8714 - val_loss: 0.5755 - val_accuracy: 0.7561
# Epoch 75/75
# 19/19 [==============================] - 0s 5ms/step - loss: 0.3103 - accuracy: 0.8816 - val_loss: 0.5698 - val_accuracy: 0.7642

# %%
# Evaluate the model
loss, accuracy = model.evaluate(X_test, y_test)
print(f'Accuracy: {accuracy:.4f}')
# Out:
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4716 - accuracy: 0.8117
# Accuracy: 0.8117

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-e213750e469e> in <cell line: 1>()
# ----> 1 y_pred = np.where(y_log>0.5,1,0)
#
# NameError: name 'y_log' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-e9c44cedfbe6> in <cell line: 2>()
#       1 from sklearn.metrics import accuracy_score
# ----> 2 accuracy_score(y_test,y_pred)
#
# NameError: name 'y_pred' is not defined
