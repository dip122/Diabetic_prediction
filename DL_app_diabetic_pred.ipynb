# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('datasets.csv')

# %%
df.head(1)
# Out:
#    6  148  72  35  0  33.6  0.627  50  1
# 0  1   85  66  29  0  26.6  0.351  31  0

# %%
df.rename(columns = {'6' : 'Pregnancies' , '148' : 'Glucose' , '72' : 'BloodPressure' , '35' : 'SkinThickness' , '0' : 'Insulin' , '33.6' : 'BMI' , '0.627' : 'DiabetesPedigreeFunction' , '50' : 'Age' , '1' : 'outcome'},inplace =True)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age  outcome
# 0                     0.351   31        0
# 1                     0.672   32        1
# 2                     0.167   21        0
# 3                     2.288   33        1
# 4                     0.201   30        0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   767.000000  767.000000     767.000000     767.000000  767.000000
# mean      3.842243  120.859192      69.101695      20.517601   79.903520
# std       3.370877   31.978468      19.368155      15.954059  115.283105
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   32.000000
# 75%       6.000000  140.000000      80.000000      32.000000  127.500000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     outcome
# count  767.000000                767.000000  767.000000  767.000000
# mean    31.990482                  0.471674   33.219035    0.348110
# std      7.889091                  0.331497   11.752296    0.476682
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243500   24.000000    0.000000
# 50%     32.000000                  0.371000   29.000000    0.000000
# 75%     36.600000                  0.625000   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 767 entries, 0 to 766
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               767 non-null    int64
#  1   Glucose                   767 non-null    int64
#  2   BloodPressure             767 non-null    int64
#  3   SkinThickness             767 non-null    int64
#  4   Insulin                   767 non-null    int64
#  5   BMI                       767 non-null    float64
#  6   DiabetesPedigreeFunction  767 non-null    float64
#  7   Age                       767 non-null    int64
#  8   outcome                   767 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.duplicated().sum()   # no duplicate value is present
# Out:
# 0

# %%
df['outcome'].value_counts()    # data is not so biased
# Out:
# 0    500
# 1    267
# Name: outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns = ['outcome']);
y = df['outcome']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2,random_state = 1)

# %%
X.shape
# Out:
# (767, 8)

# %%
y.shape
# Out:
# (767,)

# %%
X.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            1       85             66             29        0  26.6
# 1            8      183             64              0        0  23.3
# 2            1       89             66             23       94  28.1
# 3            0      137             40             35      168  43.1
# 4            5      116             74              0        0  25.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.351   31
# 1                     0.672   32
# 2                     0.167   21
# 3                     2.288   33
# 4                     0.201   30

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[ 1.49469849,  0.70529254,  0.57078307, ...,  0.73884819,
#          0.55721449,  0.58496446],
#        [ 1.7896921 ,  0.20300462, -0.37203436, ...,  1.1680149 ,
#         -0.05569033,  0.4142512 ],
#        [-1.16024406, -0.26789031,  0.57078307, ...,  1.55816646,
#         -0.91250626, -0.52467177],
#        ...,
#        [ 0.01973041,  0.20300462,  0.88505555, ...,  0.37470673,
#         -0.71237407, -0.8660983 ],
#        [ 0.90471125,  1.83544037,  0.78029806, ...,  0.47874715,
#          0.39773416,  1.52388743],
#        [-0.57025683, -1.02132219, -0.05776188, ...,  0.77786334,
#          0.13818772, -0.52467177]])

# %%
X_test_scaled
# Out:
# array([[ 0.31472402,  1.0192225 ,  0.78029806, ...,  0.8428886 ,
#          0.50092731,  0.07282466],
#        [-1.16024406,  0.07743264,  1.40884301, ..., -1.26392981,
#         -0.61543504, -1.03681157],
#        [ 2.37967934, -0.04813934,  0.46602558, ..., -0.74372773,
#         -0.62481624,  2.4628104 ],
#        ...,
#        [ 0.90471125,  0.92504351,  0.98981304, ...,  2.31245947,
#         -0.38090514,  0.24353793],
#        [ 0.31472402,  0.42275559,  0.67554056, ..., -4.1900665 ,
#          0.56659569,  3.06030683],
#        [ 0.01973041, -1.02132219, -3.61951661, ..., -0.54865195,
#          0.47278373, -0.18324524]])

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()
#1st layer 8 input so input_dim = 8 and activation function which is used is relu
# 12 repersent number of nodes in the hidden layer 1
model.add(Dense(12,input_dim = 8,activation = 'relu'))
#2nd layer ....for next layer 8 nodes is present
model.add(Dense(8,activation = 'relu'))
model.add(Dense(1,activation = 'relu'))

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 12)                108
#
#  dense_7 (Dense)             (None, 8)                 104
#
#  dense_8 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 221 (884.00 Byte)
# Trainable params: 221 (884.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss = 'binary_crossentropy',optimizer = 'Adam')  # it is a binary classification so binary_crossentropy

# %%
model.fit(X_train_scaled,y_train,epochs=100)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 2ms/step - loss: 0.9734
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8195
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.8079
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7989
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7960
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7941
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7785
# Epoch 8/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7699
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7681
# Epoch 10/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7666
# Epoch 11/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7650
# Epoch 12/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7636
# Epoch 13/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7619
# Epoch 14/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7606
# Epoch 15/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7258
# Epoch 16/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7189
# Epoch 17/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7154
# Epoch 18/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7130
# Epoch 19/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7113
# Epoch 20/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7095
# Epoch 21/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7081
# Epoch 22/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7065
# Epoch 23/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7052
# Epoch 24/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7039
# Epoch 25/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7027
# Epoch 26/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7015
# Epoch 27/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.7006
# Epoch 28/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6993
# Epoch 29/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6983
# Epoch 30/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6972
# Epoch 31/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6962
# Epoch 32/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6948
# Epoch 33/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6939
# Epoch 34/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6933
# Epoch 35/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6922
# Epoch 36/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6912
# Epoch 37/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6906
# Epoch 38/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6897
# Epoch 39/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6888
# Epoch 40/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6883
# Epoch 41/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6886
# Epoch 42/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6869
# Epoch 43/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6868
# Epoch 44/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6857
# Epoch 45/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6851
# Epoch 46/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6844
# Epoch 47/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6838
# Epoch 48/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6834
# Epoch 49/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6835
# Epoch 50/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6667
# Epoch 51/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6635
# Epoch 52/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6633
# Epoch 53/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6614
# Epoch 54/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6606
# Epoch 55/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6501
# Epoch 56/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6047
# Epoch 57/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6016
# Epoch 58/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5978
# Epoch 59/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5969
# Epoch 60/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5963
# Epoch 61/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5958
# Epoch 62/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5951
# Epoch 63/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5951
# Epoch 64/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5943
# Epoch 65/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5949
# Epoch 66/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5944
# Epoch 67/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5934
# Epoch 68/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5934
# Epoch 69/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5932
# Epoch 70/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5927
# Epoch 71/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5925
# Epoch 72/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5922
# Epoch 73/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5920
# Epoch 74/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.5918
# Epoch 75/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5917
# Epoch 76/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5911
# Epoch 77/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5907
# Epoch 78/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5907
# Epoch 79/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5905
# Epoch 80/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5901
# Epoch 81/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5898
# Epoch 82/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5893
# Epoch 83/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5895
# Epoch 84/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5890
# Epoch 85/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5888
# Epoch 86/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5888
# Epoch 87/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5883
# Epoch 88/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5880
# Epoch 89/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5878
# Epoch 90/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5876
# Epoch 91/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5875
# Epoch 92/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5872
# Epoch 93/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5865
# Epoch 94/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5866
# Epoch 95/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5866
# Epoch 96/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5862
# Epoch 97/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5860
# Epoch 98/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5858
# Epoch 99/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5854
# Epoch 100/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5849

# %%
y_log = model.predict(X_test_scaled)
y_log
# Out:
# 5/5 [==============================] - 0s 2ms/step
# array([[0.8593578 ],
#        [0.19555232],
#        [0.29286268],
#        [0.02226932],
#        [0.07190732],
#        [0.6135624 ],
#        [0.        ],
#        [0.23732418],
#        [0.18033649],
#        [0.        ],
#        [0.24900973],
#        [0.        ],
#        [0.03735744],
#        [0.06346023],
#        [0.        ],
#        [0.65371054],
#        [0.49899158],
#        [0.08033365],
#        [0.        ],
#        [0.0755024 ],
#        [0.        ],
#        [0.5069071 ],
#        [0.22506543],
#        [0.10196897],
#        [0.        ],
#        [0.03625132],
#        [0.30849662],
#        [0.02398966],
#        [0.        ],
#        [1.3658775 ],
#        [0.20164287],
#        [0.26711068],
#        [0.12639815],
#        [0.6042286 ],
#        [0.01786299],
#        [0.61284035],
#        [0.0647509 ],
#        [0.5913522 ],
#        [0.78735876],
#        [0.05825817],
#        [0.2856463 ],
#        [0.        ],
#        [0.29598674],
#        [0.45825118],
#        [0.07991751],
#        [0.13691925],
#        [0.        ],
#        [0.16510937],
#        [0.01185218],
#        [0.09030009],
#        [0.        ],
#        [0.10118038],
#        [0.02064306],
#        [0.48543376],
#        [0.08057467],
#        [0.        ],
#        [0.3241302 ],
#        [1.1903223 ],
#        [0.15309386],
#        [0.26077852],
#        [0.4975756 ],
#        [0.5354189 ],
#        [0.        ],
#        [0.67159486],
#        [0.18898146],
#        [0.12910885],
#        [0.3094926 ],
#        [0.6562073 ],
#        [0.5654719 ],
#        [0.66090935],
#        [0.5394995 ],
#        [0.5184936 ],
#        [0.5026196 ],
#        [0.        ],
#        [0.7117508 ],
#        [0.7919107 ],
#        [0.7564295 ],
#        [0.08580782],
#        [0.04966537],
#        [0.07532943],
#        [0.12069401],
#        [0.20303033],
#        [0.513003  ],
#        [0.60505795],
#        [0.44691852],
#        [0.13105914],
#        [0.61827403],
#        [0.6777353 ],
#        [0.11822692],
#        [0.07353125],
#        [0.        ],
#        [0.05301917],
#        [0.        ],
#        [0.0606566 ],
#        [0.8430755 ],
#        [0.039675  ],
#        [0.        ],
#        [0.4940345 ],
#        [0.33324367],
#        [0.17008092],
#        [0.5416296 ],
#        [0.10436886],
#        [0.08191161],
#        [0.1643037 ],
#        [0.16902125],
#        [0.02190468],
#        [0.        ],
#        [0.        ],
#        [0.3232615 ],
#        [0.        ],
#        [0.44674918],
#        [2.052161  ],
#        [0.13677369],
#        [0.49700087],
#        [0.3048646 ],
#        [0.69878334],
#        [0.        ],
#        [0.22810668],
#        [0.64315045],
#        [0.43100974],
#        [0.28579435],
#        [0.16831318],
#        [0.19810948],
#        [0.98596954],
#        [0.35986647],
#        [0.11630184],
#        [1.1931006 ],
#        [0.79115313],
#        [0.06227104],
#        [0.11851583],
#        [0.07448434],
#        [0.32996935],
#        [0.85293   ],
#        [0.437889  ],
#        [0.4589589 ],
#        [0.21725188],
#        [0.4283594 ],
#        [0.02846927],
#        [0.09404043],
#        [0.        ],
#        [1.4567086 ],
#        [0.10483194],
#        [0.05088835],
#        [0.18384533],
#        [0.        ],
#        [0.        ],
#        [0.        ],
#        [0.25503924],
#        [0.6827171 ],
#        [0.        ],
#        [0.507284  ],
#        [0.8280668 ],
#        [0.        ],
#        [0.38039973]], dtype=float32)

# %%
y_pred = np.where(y_log>0.5,1,0)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.7922077922077922
